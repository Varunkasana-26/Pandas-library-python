# %% [markdown]
# <a href="https://colab.research.google.com/github/Varunkasana-26/Pandas-library-python/blob/main/pandaslibrarypractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random as r
import string as s
import numpy as np

# %%
df = pd.DataFrame(np.arange(0,24).reshape(6,4),index=["Rows1","Rows2","Rows3","Rows4","Rows5","Rows6"], columns=["columns1","columns2","columns3","columns4"])
df.head
print(df)
# Out:
#        columns1  columns2  columns3  columns4
# Rows1         0         1         2         3
# Rows2         4         5         6         7
# Rows3         8         9        10        11
# Rows4        12        13        14        15
# Rows5        16        17        18        19
# Rows6        20        21        22        23

# %%
type(df.loc['Rows1'])
# Out:
# pandas.core.series.Series

# %%
a = df.loc[:,:].values.shape
print(a)
c = df.isnull().sum()
b = df.isnull()
print(b)
print(c)
# Out:
# (6, 4)
#        columns1  columns2  columns3  columns4
# Rows1     False     False     False     False
# Rows2     False     False     False     False
# Rows3     False     False     False     False
# Rows4     False     False     False     False
# Rows5     False     False     False     False
# Rows6     False     False     False     False
# columns1    0
# columns2    0
# columns3    0
# columns4    0
# dtype: int64

# %%
df['columns1'].unique()
# Out:
# array([ 0,  4,  8, 12, 16, 20])

# %%
df['columns1'].value_counts()
# Out:
# columns1
# 0     1
# 4     1
# 8     1
# 12    1
# 16    1
# 20    1
# Name: count, dtype: int64

# %%
df.to_csv('data.csv')

# %%
df = pd.read_csv('/content/data.csv')
df.head()
# Out:
#   Unnamed: 0  columns1  columns2  columns3  columns4
# 0      Rows1         0         1         2         3
# 1      Rows2         4         5         6         7
# 2      Rows3         8         9        10        11
# 3      Rows4        12        13        14        15
# 4      Rows5        16        17        18        19

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  6 non-null      object
#  1   columns1    6 non-null      int64
#  2   columns2    6 non-null      int64
#  3   columns3    6 non-null      int64
#  4   columns4    6 non-null      int64
# dtypes: int64(4), object(1)
# memory usage: 368.0+ bytes

# %%
df.describe()
# Out:
#         columns1   columns2   columns3   columns4
# count   6.000000   6.000000   6.000000   6.000000
# mean   10.000000  11.000000  12.000000  13.000000
# std     7.483315   7.483315   7.483315   7.483315
# min     0.000000   1.000000   2.000000   3.000000
# 25%     5.000000   6.000000   7.000000   8.000000
# 50%    10.000000  11.000000  12.000000  13.000000
# 75%    15.000000  16.000000  17.000000  18.000000
# max    20.000000  21.000000  22.000000  23.000000

# %%
df[df['columns1']>9]
# Out:
#   Unnamed: 0  columns1  columns2  columns3  columns4
# 3      Rows4        12        13        14        15
# 4      Rows5        16        17        18        19
# 5      Rows6        20        21        22        23

# %%
from io import StringIO, BytesIO

# %%
data = ('column1,column2,columns3\n'
'a,b,c\n'
'd,e,f\n')

# %%
type(data)
# Out:
# str

# %%
StringIO(data)

# %%
pd.read_csv(StringIO(data))
# Out:
#   column1 column2 columns3
# 0       a       b        c
# 1       d       e        f

# %%
df=pd.read_csv(StringIO(data), usecols =  ['column1','columns3'])

# %%
df.to_csv('practice 2')

# %%
df=pd.read_csv(StringIO(data),dtype=object)
df
# Out:
#   column1 column2 columns3
# 0       a       b        c
# 1       d       e        f
